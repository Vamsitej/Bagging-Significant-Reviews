# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel("model_binary_polarity_part4_rectified_2 (1).xlsx")

# %%
df = df.set_index('No')

# %%
df.head()
# Out:
#     money  product  service  installation  bed  quality  wood  design  \
# No
# 0       0        0        0             1    0        0     1       0
# 1       0        0        0             0    1        1     1       0
# 2       1        1        1             0    0        1     1       0
# 3       1        0        0             0    1        0     1       0
# 4       1        1        1             0    1        0     0       0
#
#     storage  delivery  rating       date
# No
# 0         0         0       3 2018-05-25
# 1         1         0       3 2018-08-25
# 2         0         0       5 2019-01-25
# 3         1         0       4 2020-06-25
# 4         0         0       5 2020-11-25

# %%
df1 = pd.read_excel("model_polarity_part4_rectified (3).xlsx")

# %%
df1 = df1.set_index('No')

# %%
df1.head()
# Out:
#      money  product  service  installation     bed  quality    wood  design  \
# No
# 0   0.0000   0.0000   0.0000        0.2732  0.0000   0.0000  0.4927     0.0
# 1   0.0000   0.0000   0.0000        0.0000 -0.5849   0.5994  0.4404     0.0
# 2   0.6249   0.7506  -0.3626        0.0000  0.0000  -0.4215  0.4404     0.0
# 3   0.3400   0.0000   0.0000        0.0000 -0.2960   0.0000  0.4404     0.0
# 4  -0.1280   0.6369   0.6369        0.0000  0.0258   0.0000  0.0000     0.0
#
#     storage  delivery  rating       date
# No
# 0    0.0000       0.0       3 2018-05-25
# 1    0.4404       0.0       3 2018-08-25
# 2    0.0000       0.0       5 2019-01-25
# 3    0.5719       0.0       4 2020-06-25
# 4    0.0000       0.0       5 2020-11-25

# %%
df.sort_values(['date'])
# Out:
#      money  product  service  installation  bed  quality  wood  design  \
# No
# 78       0        0        0             0    1        0     0       0
# 214      1        0        0             0    0        0     0       0
# 122      0        0        0             0    0        0     0       0
# 106      0        0        0             1    0        0     0       0
# 84       0        0        0             0    0        0     1       0
# ..     ...      ...      ...           ...  ...      ...   ...     ...
# 224      0        0        0             0    0        0     0       0
# 223      1        0        0             0    0        0     0       0
# 220      0        0        0             0    0        0     1       0
# 222      0        0        0             0    1        0     0       0
# 221      0        1        0             0    0        0     1       0
#
#      storage  delivery  rating       date
# No
# 78         0         0       4 2018-03-25
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.sort_values(['date'])

# %%
df.head()
# Out:
#      money  product  service  installation  bed  quality  wood  design  \
# No
# 78       0        0        0             0    1        0     0       0
# 214      1        0        0             0    0        0     0       0
# 122      0        0        0             0    0        0     0       0
# 106      0        0        0             1    0        0     0       0
# 84       0        0        0             0    0        0     1       0
#
#      storage  delivery  rating       date
# No
# 78         0         0       4 2018-03-25
# 214        0         0       5 2018-04-25
# 122        0         1       5 2018-04-25
# 106        0         0       5 2018-04-25
# 84         0         0       5 2018-04-25

# %%
df_01 = df[df['date']<= '2019-03-25' ]

# %%
df_01.shape
# Out:
# (426, 12)

# %%
df_01.describe()
# Out:
#             money     product     service  installation         bed  \
# count  387.000000  387.000000  387.000000    387.000000  387.000000
# mean     0.087855    0.253230    0.059432      0.056848    0.108527
# std      0.283451    0.435424    0.236737      0.231851    0.311448
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%      0.000000    0.000000    0.000000      0.000000    0.000000
# 50%      0.000000    0.000000    0.000000      0.000000    0.000000
# 75%      0.000000    1.000000    0.000000      0.000000    0.000000
# max      1.000000    1.000000    1.000000      1.000000    1.000000
#
#           quality        wood      design     storage    delivery      rating
# count  387.000000  387.000000  387.000000  387.000000  387.000000  387.000000
# mean     0.126615    0.087855    0.031008    0.025840    0.031008    3.684755
# std      0.332972    0.283451    0.173563    0.158863    0.173563    1.481789
# ...

# %%
df_02 = df[(df['date'] > '2019-03-25') & (df['date'] <= '2020-03-25')]

# %%
df_02.head()
# Out:
#       money  product  service  installation  bed  quality  wood  design  \
# No
# 2146      0        0        0             0    0        0     0       0
# 2152      0        0        0             0    0        0     0       0
# 103       0        0        0             0    0        0     0       0
# 2149      0        0        0             0    0        0     0       0
# 2150      0        1        0             0    0        0     0       0
#
#       storage  delivery  rating       date
# No
# 2146        0         0       2 2019-04-25
# 2152        0         0       1 2019-04-25
# 103         0         0       4 2019-04-25
# 2149        0         0       5 2019-04-25
# 2150        0         0       1 2019-04-25

# %%
df.tail()
# Out:
#      money  product  service  installation  bed  quality  wood  design  \
# No
# 224      0        0        0             0    0        0     0       0
# 223      1        0        0             0    0        0     0       0
# 220      0        0        0             0    0        0     1       0
# 222      0        0        0             0    1        0     0       0
# 221      0        1        0             0    0        0     1       0
#
#      storage  delivery  rating       date
# No
# 224        0         0       4 2021-03-24
# 223        0         0       5 2021-03-24
# 220        0         0       5 2021-03-25
# 222        0         0       5 2021-03-25
# 221        0         0       5 2021-03-25

# %%
df_03 = df[(df['date'] > '2020-03-25') & (df['date'] <= '2021-03-25')]

# %%
df_03.head()
# Out:
#       money  product  service  installation  bed  quality  wood  design  \
# No
# 1342      0        1        0             0    0        0     0       0
# 1341      1        0        0             0    0        1     0       0
# 1336      1        0        0             0    0        1     0       0
# 1339      0        0        0             0    0        0     0       0
# 1338      0        0        0             0    0        1     1       0
#
#       storage  delivery  rating       date
# No
# 1342        0         0       5 2020-04-25
# 1341        0         0       1 2020-04-25
# 1336        0         0       1 2020-04-25
# 1339        0         0       1 2020-04-25
# 1338        0         0       5 2020-04-25

# %%
df_01.shape
# Out:
# (426, 12)

# %%
df_02.shape
# Out:
# (912, 12)

# %%
df_03.shape
# Out:
# (1168, 12)

# %%
df.shape
# Out:
# (2506, 12)

# %%
df_01.head()
# Out:
#      money  product  service  installation  bed  quality  wood  design  \
# No
# 78       0        0        0             0    1        0     0       0
# 214      1        0        0             0    0        0     0       0
# 122      0        0        0             0    0        0     0       0
# 106      0        0        0             1    0        0     0       0
# 84       0        0        0             0    0        0     1       0
#
#      storage  delivery  rating       date
# No
# 78         0         0       4 2018-03-25
# 214        0         0       5 2018-04-25
# 122        0         1       5 2018-04-25
# 106        0         0       5 2018-04-25
# 84         0         0       5 2018-04-25

# %%
df1.head()
# Out:
#      money  product  service  installation     bed  quality    wood  design  \
# No
# 0   0.0000   0.0000   0.0000        0.2732  0.0000   0.0000  0.4927     0.0
# 1   0.0000   0.0000   0.0000        0.0000 -0.5849   0.5994  0.4404     0.0
# 2   0.6249   0.7506  -0.3626        0.0000  0.0000  -0.4215  0.4404     0.0
# 3   0.3400   0.0000   0.0000        0.0000 -0.2960   0.0000  0.4404     0.0
# 4  -0.1280   0.6369   0.6369        0.0000  0.0258   0.0000  0.0000     0.0
#
#     storage  delivery  rating       date
# No
# 0    0.0000       0.0       3 2018-05-25
# 1    0.4404       0.0       3 2018-08-25
# 2    0.0000       0.0       5 2019-01-25
# 3    0.5719       0.0       4 2020-06-25
# 4    0.0000       0.0       5 2020-11-25

# %%
df1.sort_values(['date'])
# Out:
#       money  product  service  installation     bed  quality    wood  design  \
# No
# 78   0.0000   0.0000      0.0        0.0000 -0.5719      0.0  0.0000     0.0
# 214  0.6249   0.0000      0.0        0.0000  0.0000      0.0  0.0000     0.0
# 122  0.0000   0.0000      0.0        0.0000  0.0000      0.0  0.0000     0.0
# 106  0.0000   0.0000      0.0        0.4404  0.0000      0.0  0.0000     0.0
# 84   0.0000   0.0000      0.0        0.0000  0.0000      0.0  0.4404     0.0
# ..      ...      ...      ...           ...     ...      ...     ...     ...
# 224  0.0000   0.0000      0.0        0.0000  0.0000      0.0  0.0000     0.0
# 223  0.3400   0.0000      0.0        0.0000  0.0000      0.0  0.0000     0.0
# 220  0.0000   0.0000      0.0        0.0000  0.0000      0.0  0.6486     0.0
# 222  0.0000   0.0000      0.0        0.0000  0.6361      0.0  0.0000     0.0
# 221  0.0000   0.4927      0.0        0.0000  0.0000      0.0  0.4404     0.0
#
# ...
